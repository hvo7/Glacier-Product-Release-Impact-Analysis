# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os

base_dir = Path(os.getcwd())

# %%
data_dir = base_dir / "Dataset"

os.chdir(data_dir)

# %%
accts = pd.read_csv("accounts.csv")

# %% [markdown]
# ## Check for duplicate columns

# %%
accts.loc[accts.duplicated(keep=False),:]
# Out:
#           industry country signup_date referral_source   plan_tier  seats  \
# 28        DevTools      US  10/28/2023         organic  Enterprise    7.0
# 36        DevTools      DE   5/12/2023             ads         Pro    5.0
# 84        DevTools      US    2/9/2023           event         Pro   38.0
# 101     HealthTech      US    8/7/2023             ads  Enterprise   20.0
# 112       DevTools      AU   7/15/2024           event         Pro   38.0
# ..             ...     ...         ...             ...         ...    ...
# 583  Cybersecurity      IN   1/17/2023         partner       Basic   42.0
# 590       DevTools      US   8/14/2023           event         Pro   64.0
# 595        FinTech      US  10/20/2023         partner  Enterprise   19.0
# 597       DevTools      CA   4/21/2024           other         Pro   24.0
# 598     HealthTech      US  12/25/2023         partner  Enterprise    1.0
#
#     account_id account_name  churn_flag  is_trial
# ...
